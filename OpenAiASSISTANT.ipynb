# %%
from openai import OpenAI

client = OpenAI()

# %%
assistant = client.beta.assistants.create(
  instructions="You are a personal math tutor. When asked a math question, write and run code to answer the question.",
  model="gpt-3.5-turbo",
  tools=[{"type": "code_interpreter"}]
)

# %%
thread = client.beta.threads.create()
thread
# Out:
# Thread(id='thread_nTyQ96LkRHhyeTgJoyj2G4VK', created_at=1700832931, metadata={}, object='thread')

# %%
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content="I need to solve the equation `3x + 11 = 14`. Can you help me?"
)

# %%
message
# Out:
# ThreadMessage(id='msg_YAePzec280XLLfyy0PlltOyH', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='I need to solve the equation `3x + 11 = 14`. Can you help me?'), type='text')], created_at=1700832943, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_nTyQ96LkRHhyeTgJoyj2G4VK')

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions="Please address the user as Jane Doe. The user has a premium account."
)

# %%
run
# Out:
# Run(id='run_BpMb8VzIHO6dvq7DNgzwWtNp', assistant_id='asst_y0wFRsYcp6ObC2w5tKFkLdmv', cancelled_at=None, completed_at=None, created_at=1700833003, expires_at=1700833603, failed_at=None, file_ids=[], instructions='Please address the user as Jane Doe. The user has a premium account.', last_error=None, metadata={}, model='gpt-3.5-turbo', object='thread.run', required_action=None, started_at=None, status='queued', thread_id='thread_nTyQ96LkRHhyeTgJoyj2G4VK', tools=[ToolAssistantToolsCode(type='code_interpreter')])

# %%
run = client.beta.threads.runs.retrieve(
  thread_id=thread.id,
  run_id=run.id
)

# %%
run
# Out:
# Run(id='run_BpMb8VzIHO6dvq7DNgzwWtNp', assistant_id='asst_y0wFRsYcp6ObC2w5tKFkLdmv', cancelled_at=None, completed_at=1700833007, created_at=1700833003, expires_at=None, failed_at=None, file_ids=[], instructions='Please address the user as Jane Doe. The user has a premium account.', last_error=None, metadata={}, model='gpt-3.5-turbo', object='thread.run', required_action=None, started_at=1700833003, status='completed', thread_id='thread_nTyQ96LkRHhyeTgJoyj2G4VK', tools=[ToolAssistantToolsCode(type='code_interpreter')])

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)
messages
# Out:
# SyncCursorPage[ThreadMessage](data=[ThreadMessage(id='msg_ddSCeCznzGEXkg6dbVApWXUz', assistant_id='asst_y0wFRsYcp6ObC2w5tKFkLdmv', content=[MessageContentText(text=Text(annotations=[], value="Of course, I can help you solve the equation `3x + 11 = 14`. To solve this equation, we can start by isolating the variable `x`. \n\nLet's go step by step:\n\n1. Subtract 11 from both sides of the equation:\n   `3x + 11 - 11 = 14 - 11`\n   Simplifying, we get:\n   `3x = 3`\n   \n2. Divide both sides of the equation by 3 to solve for `x`:\n   `3x / 3 = 3 / 3`\n   Simplifying, we have:\n   `x = 1`\n\nTherefore, the solution to the equation `3x + 11 = 14` is `x = 1`."), type='text')], created_at=1700833003, file_ids=[], metadata={}, object='thread.message', role='assistant', run_id='run_BpMb8VzIHO6dvq7DNgzwWtNp', thread_id='thread_nTyQ96LkRHhyeTgJoyj2G4VK'), ThreadMessage(id='msg_YAePzec280XLLfyy0PlltOyH', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='I need to solve the equation `3x + 11 = 14`. Can you help me?'), type='text')], created_at=1700832943, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_nTyQ96LkRHhyeTgJoyj2G4VK')], object='list', first_id='msg_ddSCeCznzGEXkg6dbVApWXUz', last_id='msg_YAePzec280XLLfyy0PlltOyH', has_more=False)
